# %%
from methodscourse.api import API

# %%
api = API(root_dir = '/mnt/c/Users/dsege/OneDrive/Desktop/MethodsCourse/')

# %%
api.detect_flies(file_ids = ['0001'])
# Out:
# Flies were already annotated for file_id: 0001 - continue with next file.

# %%
api.detect_flies(file_ids = ['0002'])

# %%
api.save_results(prefix = 'DS2_')

# %%
api.load_results()

# %%
import pandas as pd
pd.DataFrame(data = api.database.file_infos)
# Out:
#    index file_id group_id stimulus_indicator vial_id  time_passed  \
# 0   0000    0000       tg               post    _001            1
# 1   0001    0000       tg               post    _001            2
# 2   0002    0000       tg               post    _001            3
# 3   0003    0000       tg               post    _001            4
# 4   0004    0000       tg               post    _001            5
# 5   0005    0001       tg               post    _002            1
# 6   0006    0001       tg               post    _002            2
# 7   0007    0001       tg               post    _002            3
# 8   0008    0001       tg               post    _002            4
# 9   0009    0001       tg               post    _002            5
# 10  0010    0002       tg                pre    _001            1
# 11  0011    0002       tg                pre    _001            2
# 12  0012    0002       tg                pre    _001            3
# ...

# %%
api.save_results()

# %%
api.load_results()

# %%
import os
os.path.isdir('öalskjf')
# Out:
# False

# %%
for key in api.database.file_infos.keys():
    print(len(api.database.file_infos[key]))
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
api.database.

# %%
import pandas as pd

pd.DataFrame(data = api.database.file_infos)
# Out:
#    file_id group_id stimulus_indicator vial_id  time_passed  \
# 0     0000       tg               post    _001            1
# 1     0000       tg               post    _001            2
# 2     0000       tg               post    _001            3
# 3     0000       tg               post    _001            4
# 4     0000       tg               post    _001            5
# 5     0001       tg               post    _002            1
# 6     0001       tg               post    _002            2
# 7     0001       tg               post    _002            3
# 8     0001       tg               post    _002            4
# 9     0001       tg               post    _002            5
# 10    0002       tg                pre    _001            1
# 11    0002       tg                pre    _001            2
# 12    0002       tg                pre    _001            3
# 13    0002       tg                pre    _001            4
# 14    0002       tg                pre    _001            5
# ...
