# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import imageio as iio

# %% [markdown]
# Import and visualize an image:

# %%
video_filepath = '/home/pi/Desktop/test/recorded_videos/0000_wt_pre_light_001.mp4'

# %%
reader = iio.get_reader(video_filepath)
image = reader.get_data(90)
reader.close()

# %%
plt.imshow(image)

# %%
# But what does it look like in our variable?
image

# %%
image.shape

# %%
# We can do lot's of things with numpy arrays, for instance cropping it:
cropped_image = image[150:900, 800:1250]
cropped_image.shape
# Out:
# (750, 450, 3)

# %%
plt.imshow(cropped_image)

# %% [markdown]
# Well, now we need to find a way to detect the flies.. a very popular image processing package is skimage (or "scikit-image"). Can you find something usefull there?
